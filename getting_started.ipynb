# %% [markdown]
# # Getting started
#
# Welcome to the getting started guide of *JuPedSim*, we want to guide you through the first steps for setting up a simulation.
#
# First things first, to use *JuPedSim* install it via:
#
# ```bash
# pip install jupedsim
# ```
#
# Now, you are ready to set up your first simulation with *JuPedSim*.
#
# To access this Jupyter Notebook on your local machine, you can download it
# {download}`here <getting_started.ipynb>` along with the accompanying data file {download}`here <demo-data/bottleneck/040_c_56_h-.txt>`.

# %% [markdown]
# ## Let's simulate an experiment
#
# This is a bottleneck experiment conducted at the University of Wuppertal in 2018.
# You can see the basic setup of the experiment in the picture below:
#
# ```{eval-rst}
# .. figure:: demo-data/bottleneck/040_c_56_h-.png
#     :width: 400px
#     :align: center
# ```
#
# We aim to replicate the bottleneck scenario described in the experimental series linked to this [study](https://doi.org/10.34735/ped.2018.1) and detailed in the publication ["Crowds in front of bottlenecks at entrances from the perspective of physics and social psychology"](https://doi.org/10.1098/rsif.2019.0871).
#
# Our objective in this guide is to simulate this scenario using *JuPedSim*.
#
# If you use *JuPedSim* in your work, please cite it using the following information from Zenodo:
#
# [![DOI](https://zenodo.org/badge/DOI/10.5281/1293771.svg)](https://doi.org/10.5281/zenodo.1293771)

# %% [markdown]
# ## Setting up the simulation geometry
#
# The first thing to consider when setting up a simulation is the area where the agents can move.
# In this scenario, we have a rectangular room with two obstacles that form a bottleneck, as displayed above.
# These obstacles are excluded areas from the simulation, which means that agents can not move inside these obstacles.

# %%
import shapely

geometry = shapely.Polygon(
    # complete area
    [
        (3.5, -2),
        (3.5, 8),
        (-3.5, 8),
        (-3.5, -2),
    ],
    holes=[
        # left barrier
        [
            (-0.7, -1.1),
            (-0.25, -1.1),
            (-0.25, -0.15),
            (-0.4, 0.0),
            (-2.8, 0.0),
            (-2.8, 6.7),
            (-3.05, 6.7),
            (-3.05, -0.3),
            (-0.7, -0.3),
            (-0.7, -1.0),
        ],
        # right barrier
        [
            (0.25, -1.1),
            (0.7, -1.1),
            (0.7, -0.3),
            (3.05, -0.3),
            (3.05, 6.7),
            (2.8, 6.7),
            (2.8, 0.0),
            (0.4, 0.0),
            (0.25, -0.15),
            (0.25, -1.1),
        ],
    ],
)

# %% [markdown]
# This leads to the following setup:

# %%
import matplotlib.pyplot as plt
from pedpy import WalkableArea, plot_walkable_area

plot_walkable_area(walkable_area=WalkableArea(geometry)).set_aspect("equal")
plt.show()

# %% [markdown]
# In this geometric setup, we now need to define, where the agents can exit the simulation, e.g., where their target is located.
#
# For this scenario, the exit is at the end of the bottleneck.
# If we would put it at the beginning of the bottleneck, the agents would disappear, hence, they wouldn't be an obstacle for following agents.
#
# An exit can be defined as:

# %%
exit_polygon = shapely.Polygon(
    [(-0.2, -1.9), (0.2, -1.9), (0.2, -1.7), (-0.2, -1.7)]
)

# %% [markdown]
# The complete setup would then look like, where the exit is shown in red:

# %%
import matplotlib.pyplot as plt
from pedpy import MeasurementArea, WalkableArea, plot_measurement_setup

# We will use PedPy's plotting functionality, but it has no concept of exits
# hence we will show the exit as measurement area
plot_measurement_setup(
    walkable_area=WalkableArea(geometry),
    measurement_areas=[MeasurementArea(exit_polygon)],
    ma_color="r",
    ma_line_color="r",
).set_aspect("equal")
plt.show()

# %% [markdown]
# ## Distribute the agents in the geometry
#
#
# The next step is to provide the initial positions of the agents in the simulation.
# *JuPedSim* provides different helper functions to automatically distribute the agents:
#
# - distribute a given number of agents inside a polygon (see {func}`~jupedsim.distribute_by_number`)
# - distribute agents by a given density inside a polygon (see {func}`~jupedsim.distribute_by_density`)
# - ... (more methods can be found in the [API reference](/api/jupedsim/index), the names start with `distribute`)
#
# However, as we want to compare our simulation to the real-life experimental data, the agents in the simulation will start at the same positions as the pedestrians in the experiment.
# So we load the trajectory from the experiment and extract the locations at frame 0, which is the start of the experiment.

# %%
import pandas

experiment_data = pandas.read_csv(
    "040_c_56_h-.txt",
    comment="#",
    sep="\t",
    header=None,
    names=["id", "frame", "x", "y", "z"],
)
start_positions = experiment_data[experiment_data.frame == 0][["x", "y"]].values

# %% [markdown]
# ## Collision-free speed model
#
# At first, we want to run the simulation with the Collision-free speed model.
# In ["Collision-free speed model for pedestrian dynamics"](https://arxiv.org/abs/1512.05597) you can find the complete description of the model.
# To use it in *JuPedSim* we need to state, that we will use this model in the creation of the simulation object.
#
# We also need to provide the previously defined geometry and the output file, where the resulting trajectories will be stored.
# Here, we will use the built-in {class}`~jupedsim.SqliteTrajectoryWriter`, which will write the results as a `sqlite`-database.

# %%
import pathlib

import jupedsim as jps

trajectory_file = "bottleneck_cfsm.sqlite"
simulation_cfsm = jps.Simulation(
    model=jps.CollisionFreeSpeedModel(),
    geometry=geometry,
    trajectory_writer=jps.SqliteTrajectoryWriter(
        output_file=pathlib.Path(trajectory_file)
    ),
)

# %% [markdown]
# After we defined the simulation we need to add a goal, which the agents should target.
# As we already defined the exit polygon above, we can add it to the simulation as a stage.
# After adding the exit to the simulation, we need to create a journey containing that exit.
# Journeys are used to manage more complex routing situation, an explanation of the underlying routing concept can be found [here](/concepts/routing).

# %%
exit_id = simulation_cfsm.add_exit_stage(exit_polygon)
journey = jps.JourneyDescription([exit_id])
journey_id = simulation_cfsm.add_journey(journey)

# %% [markdown]
# Now we have the setup for the simulation.
# But there are no agents in simulation yet, so we need to add them.
#
# Before adding a simulation we need to define the agent specific parameters.
# In this example, all the agents will get the same parameters.
# We will now re-use the above extracted start positions of the agents.

# %%
for position in start_positions:
    simulation_cfsm.add_agent(
        jps.CollisionFreeSpeedModelAgentParameters(
            journey_id=journey_id,
            stage_id=exit_id,
            position=position,
            radius=0.12,
        )
    )

# %% [markdown]
# After, we have added the agents.
# We've got everything needed to start a simulation.
# Here, we will iterate, as long as there are agents inside the simulation, e.g., some agents have not yet reached the exit.

# %%
while (
    simulation_cfsm.agent_count() > 0
    and simulation_cfsm.iteration_count() < 2000
):
    simulation_cfsm.iterate()

# %% [markdown]
# Now, every agent has left the simulation.
# Let's have a look at the result:

# %%
import pedpy
from jupedsim.internal.notebook_utils import animate, read_sqlite_file

trajectory_data, walkable_area = read_sqlite_file(trajectory_file)
speed = pedpy.compute_individual_speed(traj_data=trajectory_data, frame_step=5)
speed = speed.merge(trajectory_data.data, on=["id", "frame"], how="left")

animate(trajectory_data, walkable_area)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Projects\Thesis\thesisenv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File d:\Projects\Thesis\thesisenv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File d:\Projects\Thesis\thesisenv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hoverinfo': 'name',
#               'line': {'color': 'grey'},
#               'mode': 'lines',
#               'name': 'Exterior',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': {'bdata': 'AAAAAAAADMAAAAAAAAAMwAAAAAAAAAxAAAAAAAAADEAAAAAAAAAMwA==', 'dtype': 'f8'},
#               'y': {'bdata': 'AAAAAAAAIEAAAAAAAAAAwAAAAAAAAADAAAAAAAAAIEAAAAAAAAAgQA==', 'dtype': 'f8'}},
#              {'hoverinfo': 'name',
#               'line': {'color': 'grey'},
#               'mode': 'lines',
#               'name': 'Obstacle',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': {'bdata': ('ZmZmZmZmBsCamZmZmZnZvwAAAAAAAN' ... 'ZmZgjAZmZmZmZmBsBmZmZmZmYGwA=='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAAAAAAAAAAAAAAAAADMzMzMzM8' ... 'zMzBpAzczMzMzMGkAAAAAAAAAAAA=='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'name',
#               'line': {'color': 'grey'},
#               'mode': 'lines',
#               'name': 'Obstacle',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': {'bdata': ('ZmZmZmZmBkBmZmZmZmYIQGZmZmZmZg' ... 'mZmZnZP2ZmZmZmZgZAZmZmZmZmBkA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('zczMzMzMGkDNzMzMzMwaQDMzMzMzM9' ... 'AAAAAAAAAAAAAAAAAAzczMzMzMGkA='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'none',
#               'marker': {'cmax': np.float64(1.1999999999875473),
#                          'cmin': 0,
#                          'color': {'bdata': ('XiJBvEOh3T/1UJGoWZnlP9cBuNYzH+' ... 'MunN0v4T90fISvt3bnP3a1IjDFTN8/'),
#                                    'dtype': 'f8'},
#                          'colorbar': {'title': {'text': 'Speed [m/s]'}},
#                          'colorscale': [[0.0, 'rgb(128,0,0)'], [0.2,
#                                         'rgb(250,0,0)'], [0.4, 'rgb(255,255,0)'],
#                                         [0.6, 'rgb(5,255,255)'], [0.8,
#                                         'rgb(0,60,170)'], [1.0, 'rgb(0,0,131)']],
#                          'size': {'bdata': ('mpmZmZmZ2T+amZmZmZnZP5qZmZmZmd' ... 'mZmZmZ2T+amZmZmZnZP5qZmZmZmdk/'),
#                                   'dtype': 'f8'}},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': {'bdata': ('XiJBvEOh3T/1UJGoWZnlP9cBuNYzH+' ... 'MunN0v4T90fISvt3bnP3a1IjDFTN8/'),
#                        'dtype': 'f8'},
#               'type': 'scatter',
#               'x': {'bdata': ('b/CFyVRBAUCKjuTyH9L9P7ivA+eMKP' ... 'Le4AuT679rmnecoiP3v40o7Q2+MJm/'),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('EoPAyqFFBUAldQKaCBvzP9V46SYxCP' ... '5AE2HDCEBR2ht8YTIQQDXvOEVHcgJA'),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 151, Pos(2.16,2.66)],
#               'type': 'scatter',
#               'x': [2.1569],
#               'y': [2.659]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 152, Pos(1.86,1.19)],
#               'type': 'scatter',
#               'x': [1.8638],
#               'y': [1.1941]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 153, Pos(1.88,1.63)],
#               'type': 'scatter',
#               'x': [1.8849],
#               'y': [1.627]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 154, Pos(1.96,2.11)],
#               'type': 'scatter',
#               'x': [1.9631],
#               'y': [2.1056]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 155, Pos(1.62,0.82)],
#               'type': 'scatter',
#               'x': [1.6221],
#               'y': [0.8243]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 156, Pos(1.97,3.25)],
#               'type': 'scatter',
#               'x': [1.9668],
#               'y': [3.2546]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 157, Pos(2.12,5.05)],
#               'type': 'scatter',
#               'x': [2.122],
#               'y': [5.0545]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 158, Pos(1.57,2.26)],
#               'type': 'scatter',
#               'x': [1.5721],
#               'y': [2.2575]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 159, Pos(1.83,4.23)],
#               'type': 'scatter',
#               'x': [1.8321],
#               'y': [4.2303]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 160, Pos(1.26,0.57)],
#               'type': 'scatter',
#               'x': [1.2563],
#               'y': [0.5686]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 161, Pos(1.60,3.31)],
#               'type': 'scatter',
#               'x': [1.6035],
#               'y': [3.3057]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 162, Pos(1.44,1.91)],
#               'type': 'scatter',
#               'x': [1.4388],
#               'y': [1.9147]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 163, Pos(1.36,1.46)],
#               'type': 'scatter',
#               'x': [1.3623],
#               'y': [1.459]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 164, Pos(1.66,5.30)],
#               'type': 'scatter',
#               'x': [1.664],
#               'y': [5.301]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 165, Pos(1.24,2.61)],
#               'type': 'scatter',
#               'x': [1.2446],
#               'y': [2.6068]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 166, Pos(1.23,4.74)],
#               'type': 'scatter',
#               'x': [1.2296],
#               'y': [4.7356]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 167, Pos(0.95,2.94)],
#               'type': 'scatter',
#               'x': [0.9518],
#               'y': [2.94]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 168, Pos(0.78,1.36)],
#               'type': 'scatter',
#               'x': [0.7771],
#               'y': [1.3642]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 169, Pos(0.71,0.72)],
#               'type': 'scatter',
#               'x': [0.7146],
#               'y': [0.7247]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 170, Pos(0.77,3.38)],
#               'type': 'scatter',
#               'x': [0.774],
#               'y': [3.3768]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 171, Pos(0.53,1.70)],
#               'type': 'scatter',
#               'x': [0.5291],
#               'y': [1.7029]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 172, Pos(0.66,5.20)],
#               'type': 'scatter',
#               'x': [0.6637],
#               'y': [5.2047]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 173, Pos(0.50,2.24)],
#               'type': 'scatter',
#               'x': [0.5012],
#               'y': [2.243]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 174, Pos(0.46,2.82)],
#               'type': 'scatter',
#               'x': [0.464],
#               'y': [2.8215]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 175, Pos(0.30,0.35)],
#               'type': 'scatter',
#               'x': [0.2982],
#               'y': [0.3502]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 176, Pos(0.26,0.08)],
#               'type': 'scatter',
#               'x': [0.2599],
#               'y': [0.0785]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 177, Pos(0.42,4.06)],
#               'type': 'scatter',
#               'x': [0.4186],
#               'y': [4.0625]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 178, Pos(0.36,4.73)],
#               'type': 'scatter',
#               'x': [0.3605],
#               'y': [4.7284]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 179, Pos(0.26,3.41)],
#               'type': 'scatter',
#               'x': [0.2606],
#               'y': [3.4112]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 180, Pos(0.15,0.97)],
#               'type': 'scatter',
#               'x': [0.1499],
#               'y': [0.9724]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 181, Pos(0.13,5.41)],
#               'type': 'scatter',
#               'x': [0.127],
#               'y': [5.4079]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 182, Pos(-0.04,1.68)],
#               'type': 'scatter',
#               'x': [-0.043],
#               'y': [1.6813]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 183, Pos(-0.04,4.51)],
#               'type': 'scatter',
#               'x': [-0.0434],
#               'y': [4.5088]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 184, Pos(-0.11,3.89)],
#               'type': 'scatter',
#               'x': [-0.1103],
#               'y': [3.8927]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 185, Pos(-0.15,1.34)],
#               'type': 'scatter',
#               'x': [-0.1546],
#               'y': [1.3419]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 186, Pos(-0.22,2.53)],
#               'type': 'scatter',
#               'x': [-0.2236],
#               'y': [2.5277]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 187, Pos(-0.23,0.66)],
#               'type': 'scatter',
#               'x': [-0.2322],
#               'y': [0.661]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 188, Pos(-0.25,2.93)],
#               'type': 'scatter',
#               'x': [-0.2479],
#               'y': [2.9321]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 189, Pos(-0.31,5.29)],
#               'type': 'scatter',
#               'x': [-0.3131],
#               'y': [5.2864]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 190, Pos(-0.31,0.24)],
#               'type': 'scatter',
#               'x': [-0.3056],
#               'y': [0.2423]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 191, Pos(-0.46,1.90)],
#               'type': 'scatter',
#               'x': [-0.4615],
#               'y': [1.9038]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 192, Pos(-0.63,1.00)],
#               'type': 'scatter',
#               'x': [-0.6336],
#               'y': [1.0016]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 193, Pos(-0.68,1.54)],
#               'type': 'scatter',
#               'x': [-0.6823],
#               'y': [1.5366]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 194, Pos(-0.86,4.64)],
#               'type': 'scatter',
#               'x': [-0.858],
#               'y': [4.6408]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 195, Pos(-0.87,5.10)],
#               'type': 'scatter',
#               'x': [-0.8667],
#               'y': [5.1021]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 196, Pos(-1.04,3.32)],
#               'type': 'scatter',
#               'x': [-1.0364],
#               'y': [3.3157]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 197, Pos(-1.16,1.92)],
#               'type': 'scatter',
#               'x': [-1.1572],
#               'y': [1.924]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 198, Pos(-1.38,4.80)],
#               'type': 'scatter',
#               'x': [-1.3825],
#               'y': [4.8049]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 199, Pos(-1.40,4.44)],
#               'type': 'scatter',
#               'x': [-1.4027],
#               'y': [4.4361]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 200, Pos(-1.15,0.30)],
#               'type': 'scatter',
#               'x': [-1.152],
#               'y': [0.2979]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 201, Pos(-1.25,1.38)],
#               'type': 'scatter',
#               'x': [-1.248],
#               'y': [1.3837]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 202, Pos(-1.50,3.05)],
#               'type': 'scatter',
#               'x': [-1.5049],
#               'y': [3.0546]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 203, Pos(-1.71,1.13)],
#               'type': 'scatter',
#               'x': [-1.7115],
#               'y': [1.1332]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 204, Pos(-2.26,4.08)],
#               'type': 'scatter',
#               'x': [-2.2579],
#               'y': [4.0778]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 205, Pos(-2.42,3.67)],
#               'type': 'scatter',
#               'x': [-2.4216],
#               'y': [3.6734]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 206, Pos(-2.56,4.55)],
#               'type': 'scatter',
#               'x': [-2.5593],
#               'y': [4.554]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 207, Pos(-2.11,1.47)],
#               'type': 'scatter',
#               'x': [-2.1075],
#               'y': [1.4667]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 208, Pos(-0.38,4.96)],
#               'type': 'scatter',
#               'x': [-0.3806],
#               'y': [4.96]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 209, Pos(1.07,5.08)],
#               'type': 'scatter',
#               'x': [1.0742],
#               'y': [5.0849]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 210, Pos(-1.04,5.56)],
#               'type': 'scatter',
#               'x': [-1.044],
#               'y': [5.564]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 211, Pos(-0.89,2.43)],
#               'type': 'scatter',
#               'x': [-0.8855],
#               'y': [2.4317]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 212, Pos(-2.25,5.52)],
#               'type': 'scatter',
#               'x': [-2.2508],
#               'y': [5.5185]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 213, Pos(-1.31,2.41)],
#               'type': 'scatter',
#               'x': [-1.3128],
#               'y': [2.4105]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 214, Pos(-0.56,5.55)],
#               'type': 'scatter',
#               'x': [-0.5566],
#               'y': [5.547]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 215, Pos(0.81,4.70)],
#               'type': 'scatter',
#               'x': [0.811],
#               'y': [4.697]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 216, Pos(0.30,5.89)],
#               'type': 'scatter',
#               'x': [0.2997],
#               'y': [5.8893]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 217, Pos(-1.22,0.86)],
#               'type': 'scatter',
#               'x': [-1.2233],
#               'y': [0.856]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 218, Pos(-1.67,2.07)],
#               'type': 'scatter',
#               'x': [-1.6703],
#               'y': [2.068]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 219, Pos(-0.28,5.96)],
#               'type': 'scatter',
#               'x': [-0.2828],
#               'y': [5.9605]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 220, Pos(-0.68,4.04)],
#               'type': 'scatter',
#               'x': [-0.6785],
#               'y': [4.0353]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 221, Pos(-0.48,3.35)],
#               'type': 'scatter',
#               'x': [-0.4792],
#               'y': [3.3467]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 222, Pos(-1.05,4.26)],
#               'type': 'scatter',
#               'x': [-1.0485],
#               'y': [4.2596]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 223, Pos(-0.86,3.10)],
#               'type': 'scatter',
#               'x': [-0.8617],
#               'y': [3.0954]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 224, Pos(-1.45,4.05)],
#               'type': 'scatter',
#               'x': [-1.4462],
#               'y': [4.0492]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 1, 'size': 1},
#               'mode': 'markers',
#               'showlegend': False,
#               'text': [ID: 225, Pos(-0.02,2.31)],
#               'type': 'scatter',
#               'x': [-0.0246],
#               'y': [2.3058]}],
#     'frames': [{'data': [{'hoverinfo': 'name',
#                           'line': {'color': 'grey'},
#                           'mode': 'lines',
#                           'name': 'Exterior',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': {'bdata': 'AAAAAAAADMAAAAAAAAAMwAAAAAAAAAxAAAAAAAAADEAAAAAAAAAMwA==', 'dtype': 'f8'},
#                           'y': {'bdata': 'AAAAAAAAIEAAAAAAAAAAwAAAAAAAAADAAAAAAAAAIEAAAAAAAAAgQA==', 'dtype': 'f8'}},
#                          {'hoverinfo': 'name',
#                           'line': {'color': 'grey'},
#                           'mode': 'lines',
#                           'name': 'Obstacle',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': {'bdata': ('ZmZmZmZmBsCamZmZmZnZvwAAAAAAAN' ... 'ZmZgjAZmZmZmZmBsBmZmZmZmYGwA=='),
#                                 'dtype': 'f8'},
#                           'y': {'bdata': ('AAAAAAAAAAAAAAAAAAAAADMzMzMzM8' ... 'zMzBpAzczMzMzMGkAAAAAAAAAAAA=='),
#                                 'dtype': 'f8'}},
#                          {'hoverinfo': 'name',
#                           'line': {'color': 'grey'},
#                           'mode': 'lines',
#                           'name': 'Obstacle',
#                           'showlegend': False,
#                           'type': 'scatter',
#                           'x': {'bdata': ('ZmZmZmZmBkBmZmZmZmYIQGZmZmZmZg' ... 'mZmZnZP2ZmZmZmZgZAZmZmZmZmBkA='),
#                                 'dtype': 'f8'},
#                           'y': {'bdata': ('zczMzMzMGkDNzMzMzMwaQDMzMzMzM9' ... 'AAAAAAAAAAAAAAAAAAzczMzMzMGkA='),
#                                 'dtype': 'f8'}},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 151, Pos(2.16,2.66)],
#                           'type': 'scatter',
#                           'x': [2.1569],
#                           'y': [2.659]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 152, Pos(1.86,1.19)],
#                           'type': 'scatter',
#                           'x': [1.8638],
#                           'y': [1.1941]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 153, Pos(1.88,1.63)],
#                           'type': 'scatter',
#                           'x': [1.8849],
#                           'y': [1.627]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 154, Pos(1.96,2.11)],
#                           'type': 'scatter',
#                           'x': [1.9631],
#                           'y': [2.1056]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 155, Pos(1.62,0.82)],
#                           'type': 'scatter',
#                           'x': [1.6221],
#                           'y': [0.8243]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 156, Pos(1.97,3.25)],
#                           'type': 'scatter',
#                           'x': [1.9668],
#                           'y': [3.2546]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 157, Pos(2.12,5.05)],
#                           'type': 'scatter',
#                           'x': [2.122],
#                           'y': [5.0545]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 158, Pos(1.57,2.26)],
#                           'type': 'scatter',
#                           'x': [1.5721],
#                           'y': [2.2575]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 159, Pos(1.83,4.23)],
#                           'type': 'scatter',
#                           'x': [1.8321],
#                           'y': [4.2303]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 160, Pos(1.26,0.57)],
#                           'type': 'scatter',
#                           'x': [1.2563],
#                           'y': [0.5686]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 161, Pos(1.60,3.31)],
#                           'type': 'scatter',
#                           'x': [1.6035],
#                           'y': [3.3057]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 162, Pos(1.44,1.91)],
#                           'type': 'scatter',
#                           'x': [1.4388],
#                           'y': [1.9147]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 163, Pos(1.36,1.46)],
#                           'type': 'scatter',
#                           'x': [1.3623],
#                           'y': [1.459]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 164, Pos(1.66,5.30)],
#                           'type': 'scatter',
#                           'x': [1.664],
#                           'y': [5.301]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 165, Pos(1.24,2.61)],
#                           'type': 'scatter',
#                           'x': [1.2446],
#                           'y': [2.6068]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 166, Pos(1.23,4.74)],
#                           'type': 'scatter',
#                           'x': [1.2296],
#                           'y': [4.7356]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 167, Pos(0.95,2.94)],
#                           'type': 'scatter',
#                           'x': [0.9518],
#                           'y': [2.94]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 168, Pos(0.78,1.36)],
#                           'type': 'scatter',
#                           'x': [0.7771],
#                           'y': [1.3642]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 169, Pos(0.71,0.72)],
#                           'type': 'scatter',
#                           'x': [0.7146],
#                           'y': [0.7247]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 170, Pos(0.77,3.38)],
#                           'type': 'scatter',
#                           'x': [0.774],
#                           'y': [3.3768]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 171, Pos(0.53,1.70)],
#                           'type': 'scatter',
#                           'x': [0.5291],
#                           'y': [1.7029]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 172, Pos(0.66,5.20)],
#                           'type': 'scatter',
#                           'x': [0.6637],
#                           'y': [5.2047]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 173, Pos(0.50,2.24)],
#                           'type': 'scatter',
#                           'x': [0.5012],
#                           'y': [2.243]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 174, Pos(0.46,2.82)],
#                           'type': 'scatter',
#                           'x': [0.464],
#                           'y': [2.8215]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 175, Pos(0.30,0.35)],
#                           'type': 'scatter',
#                           'x': [0.2982],
#                           'y': [0.3502]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 176, Pos(0.26,0.08)],
#                           'type': 'scatter',
#                           'x': [0.2599],
#                           'y': [0.0785]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 177, Pos(0.42,4.06)],
#                           'type': 'scatter',
#                           'x': [0.4186],
#                           'y': [4.0625]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 178, Pos(0.36,4.73)],
#                           'type': 'scatter',
#                           'x': [0.3605],
#                           'y': [4.7284]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 179, Pos(0.26,3.41)],
#                           'type': 'scatter',
#                           'x': [0.2606],
#                           'y': [3.4112]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 180, Pos(0.15,0.97)],
#                           'type': 'scatter',
#                           'x': [0.1499],
#                           'y': [0.9724]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 181, Pos(0.13,5.41)],
#                           'type': 'scatter',
#                           'x': [0.127],
#                           'y': [5.4079]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 182, Pos(-0.04,1.68)],
#                           'type': 'scatter',
#                           'x': [-0.043],
#                           'y': [1.6813]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 183, Pos(-0.04,4.51)],
#                           'type': 'scatter',
#                           'x': [-0.0434],
#                           'y': [4.5088]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 184, Pos(-0.11,3.89)],
#                           'type': 'scatter',
#                           'x': [-0.1103],
#                           'y': [3.8927]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 185, Pos(-0.15,1.34)],
#                           'type': 'scatter',
#                           'x': [-0.1546],
#                           'y': [1.3419]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 186, Pos(-0.22,2.53)],
#                           'type': 'scatter',
#                           'x': [-0.2236],
#                           'y': [2.5277]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 187, Pos(-0.23,0.66)],
#                           'type': 'scatter',
#                           'x': [-0.2322],
#                           'y': [0.661]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 188, Pos(-0.25,2.93)],
#                           'type': 'scatter',
#                           'x': [-0.2479],
#                           'y': [2.9321]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 189, Pos(-0.31,5.29)],
#                           'type': 'scatter',
#                           'x': [-0.3131],
#                           'y': [5.2864]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 190, Pos(-0.31,0.24)],
#                           'type': 'scatter',
#                           'x': [-0.3056],
#                           'y': [0.2423]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 191, Pos(-0.46,1.90)],
#                           'type': 'scatter',
#                           'x': [-0.4615],
#                           'y': [1.9038]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 192, Pos(-0.63,1.00)],
#                           'type': 'scatter',
#                           'x': [-0.6336],
#                           'y': [1.0016]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 193, Pos(-0.68,1.54)],
#                           'type': 'scatter',
#                           'x': [-0.6823],
#                           'y': [1.5366]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 194, Pos(-0.86,4.64)],
#                           'type': 'scatter',
#                           'x': [-0.858],
#                           'y': [4.6408]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 195, Pos(-0.87,5.10)],
#                           'type': 'scatter',
#                           'x': [-0.8667],
#                           'y': [5.1021]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 196, Pos(-1.04,3.32)],
#                           'type': 'scatter',
#                           'x': [-1.0364],
#                           'y': [3.3157]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 197, Pos(-1.16,1.92)],
#                           'type': 'scatter',
#                           'x': [-1.1572],
#                           'y': [1.924]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 198, Pos(-1.38,4.80)],
#                           'type': 'scatter',
#                           'x': [-1.3825],
#                           'y': [4.8049]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 199, Pos(-1.40,4.44)],
#                           'type': 'scatter',
#                           'x': [-1.4027],
#                           'y': [4.4361]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 200, Pos(-1.15,0.30)],
#                           'type': 'scatter',
#                           'x': [-1.152],
#                           'y': [0.2979]},
#                          {'hoverinfo': 'text',
#                           'marker': {'opacity': 1, 'size': 1},
#                           'mode': 'markers',
#                           'showlegend': False,
#                           'text': [ID: 201, Pos(-1.25,1.38)],
#                           'type': 'scatter',
#                           'x': [-1.248],
#                           'y': [1.3837]},
# ...
#                            'y1': 0.2423},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.4615,
#                            'x1': -0.4615,
#                            'y0': 1.9038,
#                            'y1': 1.9038},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.6336,
#                            'x1': -0.6336,
#                            'y0': 1.0016,
#                            'y1': 1.0016},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.6823,
#                            'x1': -0.6823,
#                            'y0': 1.5366,
#                            'y1': 1.5366},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.858,
#                            'x1': -0.858,
#                            'y0': 4.6408,
#                            'y1': 4.6408},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.8667,
#                            'x1': -0.8667,
#                            'y0': 5.1021,
#                            'y1': 5.1021},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.0364,
#                            'x1': -1.0364,
#                            'y0': 3.3157,
#                            'y1': 3.3157},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.1572,
#                            'x1': -1.1572,
#                            'y0': 1.924,
#                            'y1': 1.924},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.3825,
#                            'x1': -1.3825,
#                            'y0': 4.8049,
#                            'y1': 4.8049},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.4027,
#                            'x1': -1.4027,
#                            'y0': 4.4361,
#                            'y1': 4.4361},
#                           {'line': {'color': 'white', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.152,
#                            'x1': -1.152,
#                            'y0': 0.2979,
#                            'y1': 0.2979},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.248,
#                            'x1': -1.248,
#                            'y0': 1.3837,
#                            'y1': 1.3837},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.5049,
#                            'x1': -1.5049,
#                            'y0': 3.0546,
#                            'y1': 3.0546},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.7115,
#                            'x1': -1.7115,
#                            'y0': 1.1332,
#                            'y1': 1.1332},
#                           {'line': {'color': 'white', 'width': 3},
#                            'type': 'line',
#                            'x0': -2.2579,
#                            'x1': -2.2579,
#                            'y0': 4.0778,
#                            'y1': 4.0778},
#                           {'line': {'color': 'white', 'width': 3},
#                            'type': 'line',
#                            'x0': -2.4216,
#                            'x1': -2.4216,
#                            'y0': 3.6734,
#                            'y1': 3.6734},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -2.5593,
#                            'x1': -2.5593,
#                            'y0': 4.554,
#                            'y1': 4.554},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -2.1075,
#                            'x1': -2.1075,
#                            'y0': 1.4667,
#                            'y1': 1.4667},
#                           {'line': {'color': 'white', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.3806,
#                            'x1': -0.3806,
#                            'y0': 4.96,
#                            'y1': 4.96},
#                           {'line': {'color': 'white', 'width': 3},
#                            'type': 'line',
#                            'x0': 1.0742,
#                            'x1': 1.0742,
#                            'y0': 5.0849,
#                            'y1': 5.0849},
#                           {'line': {'color': 'white', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.044,
#                            'x1': -1.044,
#                            'y0': 5.564,
#                            'y1': 5.564},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.8855,
#                            'x1': -0.8855,
#                            'y0': 2.4317,
#                            'y1': 2.4317},
#                           {'line': {'color': 'white', 'width': 3},
#                            'type': 'line',
#                            'x0': -2.2508,
#                            'x1': -2.2508,
#                            'y0': 5.5185,
#                            'y1': 5.5185},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.3128,
#                            'x1': -1.3128,
#                            'y0': 2.4105,
#                            'y1': 2.4105},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.5566,
#                            'x1': -0.5566,
#                            'y0': 5.547,
#                            'y1': 5.547},
#                           {'line': {'color': 'white', 'width': 3},
#                            'type': 'line',
#                            'x0': 0.811,
#                            'x1': 0.811,
#                            'y0': 4.697,
#                            'y1': 4.697},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': 0.2997,
#                            'x1': 0.2997,
#                            'y0': 5.8893,
#                            'y1': 5.8893},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.2233,
#                            'x1': -1.2233,
#                            'y0': 0.856,
#                            'y1': 0.856},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.6703,
#                            'x1': -1.6703,
#                            'y0': 2.068,
#                            'y1': 2.068},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.2828,
#                            'x1': -0.2828,
#                            'y0': 5.9605,
#                            'y1': 5.9605},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.6785,
#                            'x1': -0.6785,
#                            'y0': 4.0353,
#                            'y1': 4.0353},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.4792,
#                            'x1': -0.4792,
#                            'y0': 3.3467,
#                            'y1': 3.3467},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.0485,
#                            'x1': -1.0485,
#                            'y0': 4.2596,
#                            'y1': 4.2596},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.8617,
#                            'x1': -0.8617,
#                            'y0': 3.0954,
#                            'y1': 3.0954},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -1.4462,
#                            'x1': -1.4462,
#                            'y0': 4.0492,
#                            'y1': 4.0492},
#                           {'line': {'color': 'black', 'width': 3},
#                            'type': 'line',
#                            'x0': -0.0246,
#                            'x1': -0.0246,
#                            'y0': 2.3058,
#                            'y1': 2.3058}],
#                'sliders': [{'active': 0,
#                             'currentvalue': {'font': {'size': 20},
#                                              'prefix': 'Frame:',
#                                              'visible': True,
#                                              'xanchor': 'right'},
#                             'len': 0.9,
#                             'pad': {'b': 10, 't': 50},
#                             'steps': [{'args': [['0'], {'frame': {'duration': 100,
#                                                 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '0',
#                                        'method': 'animate'},
#                                       {'args': [['50'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '50',
#                                        'method': 'animate'},
#                                       {'args': [['100'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '100',
#                                        'method': 'animate'},
#                                       {'args': [['150'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '150',
#                                        'method': 'animate'},
#                                       {'args': [['200'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '200',
#                                        'method': 'animate'},
#                                       {'args': [['250'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '250',
#                                        'method': 'animate'},
#                                       {'args': [['300'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '300',
#                                        'method': 'animate'},
#                                       {'args': [['350'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '350',
#                                        'method': 'animate'},
#                                       {'args': [['400'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '400',
#                                        'method': 'animate'},
#                                       {'args': [['450'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '450',
#                                        'method': 'animate'},
#                                       {'args': [['500'], {'frame': {'duration':
#                                                 100, 'redraw': True}, 'mode':
#                                                 'immediate', 'transition':
#                                                 {'duration': 500}}],
#                                        'label': '500',
#                                        'method': 'animate'}],
#                             'transition': {'duration': 100, 'easing': 'cubic-in-out'},
#                             'x': 0.1,
#                             'xanchor': 'left',
#                             'y': 0,
#                             'yanchor': 'top'}],
#                'template': '...',
#                'title': {'text': '<b>Number of Agents: 75</b>', 'x': 0.5},
#                'updatemenus': [{'buttons': [{'args': [None, {'frame': {'duration':
#                                                       100, 'redraw': True},
#                                                       'fromcurrent': True}],
#                                              'label': 'Play',
#                                              'method': 'animate'}],
#                                 'direction': 'left',
#                                 'pad': {'r': 10, 't': 87},
#                                 'showactive': False,
#                                 'type': 'buttons',
#                                 'x': 0.1,
#                                 'xanchor': 'right',
#                                 'y': 0,
#                                 'yanchor': 'top'}],
#                'width': 800,
#                'xaxis': {'range': [-4.0, 4.0]},
#                'yaxis': {'range': [-2.5, 8.5], 'scaleanchor': 'x', 'scaleratio': 1}}
# })

# %% [markdown]
# We have set up a first simple simulation with *JuPedSim*.
# The results are saved in trajectory files, which can be used for further analyzes.
#
#
# For more examples, how to set up simulations have a look at the following notebooks:
#
# - [Movement around corners](corner)
# - [Movement through bottlenecks](double-bottleneck)
# - [How to work with Journeys](journey)
# - [Lane formation in bi-directional flow](lane-formation)
# - [Modelling Motivation](motivation)
# - [Waiting in Queues](queues_waiting)
# - [How Route Choice can Impact Evacuation Times](routing)
# - [Simulating Single-File Movement](single-file)
#
# We would love to hear some [feedback](https://www.github.com/PedestrianDynamics/jupedsim/discussions) from you!

# %% [markdown]
# ## Comparison
#
# After simulating a bottleneck scenario with the initial positions as in the experimental setup, we now want to compare the simulation results with the experiment results.
# The first step here, is to have a look at the trajectories of both:

# %%
import pathlib

import matplotlib.pyplot as plt
import pedpy

experimental_trajectories = pedpy.load_trajectory(
    trajectory_file=pathlib.Path("040_c_56_h-.txt")
)

cfsm_data, walkable_area = read_sqlite_file(trajectory_file)

fig = plt.figure()

ax1 = fig.add_subplot(121, aspect="equal")
ax1.set_title("experimental data")
pedpy.plot_trajectories(
    traj=experimental_trajectories,
    axes=ax1,
    walkable_area=pedpy.WalkableArea(geometry),
)

ax2 = fig.add_subplot(122, aspect="equal")
ax2.set_title("Collision free speed model")
pedpy.plot_trajectories(
    traj=cfsm_data, axes=ax2, walkable_area=pedpy.WalkableArea(geometry)
)
plt.show()

# %% [markdown]
# But we do not only want to have a qualitative comparision, but also a quantitive one.
# We will use [PedPy](https://pedpy.readthedocs.io) for this analysis, it is a Python library designed for analysing pedestrian movement data.
#
#
# So, we want to compare the flow of the data sets at the bottleneck.
# First, we create a measurement line at the beginning of the bottleneck:

# %%
import pedpy

measurement_line = pedpy.MeasurementLine([(0.35, 0), (-0.35, 0)])

# %%
import pedpy

pedpy.plot_measurement_setup(
    walkable_area=walkable_area,
    measurement_lines=[measurement_line],
    ml_color="red",
    ml_width=2,
).set_aspect("equal")
plt.show()

# %% [markdown]
# For this line we can then compute the flow:

# %%
import pedpy

nt_experiment, _ = pedpy.compute_n_t(
    traj_data=experimental_trajectories,
    measurement_line=measurement_line,
)

nt_cfsm, _ = pedpy.compute_n_t(
    traj_data=cfsm_data,
    measurement_line=measurement_line,
)

# %% [markdown]
# The results can be seen here:

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("N-t")
ax.plot(
    nt_experiment["time"],
    nt_experiment["cumulative_pedestrians"],
    label="experiment",
)
ax.plot(nt_cfsm["time"], nt_cfsm["cumulative_pedestrians"], label="cfsm")
ax.legend()
ax.set_xlabel("t / s")
ax.set_ylabel("# pedestrians")
plt.show()
